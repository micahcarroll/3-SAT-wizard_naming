# %%
import runner
import numpy as np
import matplotlib.pyplot as plt

# %%
w = np.arange(10, 50, 1)
f = lambda x: runner.run(x, 100)[0]
nw = np.vectorize(f)
plt.plot(w, nw(w))
plt.show()

# %%
c = np.arange(1, 500, 20)
f2 = lambda x: runner.run(20, x)[0]
nc = np.vectorize(f2)
plt.plot(c, nc(c))
plt.show()

# %%
c = np.arange(1, 500, 20)
f2 = lambda x: runner.run(35, x)[0]
nc = np.vectorize(f2)
plt.plot(c, nc(c))
plt.show()

# %%
c = np.arange(1, 500, 20)
f2 = lambda x: runner.run(50, x)[0]
nc = np.vectorize(f2)
plt.plot(c, nc(c))
plt.show()

# %%
c = np.arange(1, 100, 2)
f2 = lambda x: runner.run(20, x)[0]
nc = np.vectorize(f2)
plt.plot(c, nc(c))
plt.show()

# %%
c = np.arange(400, 500, 2)
f2 = lambda x: runner.run(20, x)[0]
nc = np.vectorize(f2)
plt.plot(c, nc(c))
plt.show()

# %%
c = np.arange(1, 500, 20)
f2 = lambda x: runner.run(35, x, True)[0]
f2_e = lambda x: runner.run(35, x, True)[1]
nc = np.vectorize(f2)
nc_2 = np.vectorize(f2_e)
plt.plot(c, nc(c), c, nc_2(c))
plt.show()
# Out:
# CHECK PASSED!
# CHECK PASSED!
# CHECK PASSED!
# CHECK PASSED!
# CHECK PASSED!
# CHECK PASSED!
# CHECK PASSED!
# CHECK PASSED!
# CHECK PASSED!
# CHECK PASSED!
# CHECK PASSED!
# CHECK PASSED!
# CHECK PASSED!
# CHECK PASSED!
# CHECK PASSED!
# CHECK PASSED!
# CHECK PASSED!
# CHECK PASSED!
# CHECK PASSED!
# CHECK PASSED!
# CHECK PASSED!
# CHECK PASSED!
# CHECK PASSED!
# CHECK PASSED!
# CHECK PASSED!
# CHECK PASSED!
# CHECK PASSED!
# CHECK PASSED!
# CHECK PASSED!
# CHECK PASSED!
# CHECK PASSED!
# CHECK PASSED!
# CHECK PASSED!
# CHECK PASSED!
# CHECK PASSED!
# CHECK PASSED!
# CHECK PASSED!
# CHECK PASSED!
# CHECK PASSED!
# CHECK PASSED!
# CHECK PASSED!
# CHECK PASSED!
# CHECK PASSED!
# CHECK PASSED!
# CHECK PASSED!
# CHECK PASSED!
# CHECK PASSED!
# CHECK PASSED!
# CHECK PASSED!
# CHECK PASSED!
# CHECK PASSED!
# CHECK PASSED!

# %%
f2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-575c5638d602> in <module>()
# ----> 1 f2
#
# NameError: name 'f2' is not defined
