# %%
import runner
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # 3SAT

# %% [markdown]
# ## Runtime and errors with respect to number of wizards

# %%
wizards = np.arange(10, 50, 1);
time = np.vectorize(lambda x: runner.run(x, 100)[0]);
errors = np.vectorize(lambda x: runner.run(x, 100)[1]);
plt.plot(wizards, time(wizards), wizards, errors(wizards));
plt.show()

# %% [markdown]
# ## Runtime and errors with respect to number of constraints (20 wizards)

# %%
constraints = np.arange(1, 500, 20)
time = np.vectorize(lambda x: runner.run(20, x)[0])
errors = np.vectorize(lambda x: runner.run(20, x)[1])
plt.plot(constraints, time(constraints), constraints, errors(constraints));
plt.show()

# %% [markdown]
# ## Runtime and errors with respect to number of constraints (35 wizards)

# %%
constraints = np.arange(1, 500, 20)
time = np.vectorize(lambda x: runner.run(35, x)[0])
errors = np.vectorize(lambda x: runner.run(35, x)[1])
plt.plot(constraints, time(constraints), constraints, errors(constraints));
plt.show()

# %% [markdown]
# ## Runtime and errors with respect to number of constraints (50 wizards)

# %%
constraints = np.arange(1, 500, 20)
time = np.vectorize(lambda x: runner.run(50, x)[0])
errors = np.vectorize(lambda x: runner.run(50, x)[1])
plt.plot(constraints, time(constraints), constraints, errors(constraints));
plt.show()

# %% [markdown]
# ## Runtime and errors with respect to number of constraints (20 wizards)

# %%
c = np.arange(1, 500, 20)
f2 = lambda x: runner.run(35, x, True)[0]
f2_e = lambda x: runner.run(35, x, True)[1]
nc = np.vectorize(f2)
nc_2 = np.vectorize(f2_e)
plt.plot(c, nc(c), c, nc_2(c));
plt.show()
# Out:
# 1 ERRORS found!
# 1 ERRORS found!
# 1 ERRORS found!
# 1 ERRORS found!
# WTF BRO U GOT AN ERROR
# 1 ERRORS found!
# 1 ERRORS found!
# 1 ERRORS found!
# 1 ERRORS found!
# 1 ERRORS found!
# 1 ERRORS found!
# 1 ERRORS found!
# 1 ERRORS found!
# 1 ERRORS found!
# 1 ERRORS found!
# 4 ERRORS found!
# 5 ERRORS found!
# 7 ERRORS found!
# 8 ERRORS found!
# 9 ERRORS found!
# 9 ERRORS found!
# WTF BRO U GOT AN ERROR
# 1 ERRORS found!
# 1 ERRORS found!
# 1 ERRORS found!
# 1 ERRORS found!
# 2 ERRORS found!
# 3 ERRORS found!
# 3 ERRORS found!
# 3 ERRORS found!
# 4 ERRORS found!
# 4 ERRORS found!
# 7 ERRORS found!
# 7 ERRORS found!
# 7 ERRORS found!
# WTF BRO U GOT AN ERROR
# 2 ERRORS found!
# 2 ERRORS found!
# 2 ERRORS found!
# 2 ERRORS found!
# 2 ERRORS found!
# 3 ERRORS found!
# 3 ERRORS found!
# 3 ERRORS found!
# 3 ERRORS found!
# 3 ERRORS found!
# 3 ERRORS found!
# 3 ERRORS found!
# 6 ERRORS found!
# 8 ERRORS found!
# 10 ERRORS found!
# 11 ERRORS found!
# 13 ERRORS found!
# 13 ERRORS found!
# ...

# %%
c = np.arange(1, 500, 20)
f2 = lambda x: runner.run(20, x, True)[0]
f2_e = lambda x: runner.run(20, x, True)[1]
nc = np.vectorize(f2)
nc_2 = np.vectorize(f2_e)
plt.plot(c, nc(c), c, nc_2(c));
plt.show()
# Out:
# 1 ERRORS found!
# 2 ERRORS found!
# 2 ERRORS found!
# 2 ERRORS found!
# 2 ERRORS found!
# 3 ERRORS found!
# 6 ERRORS found!
# 6 ERRORS found!
# WTF BRO U GOT AN ERROR
# 1 ERRORS found!
# 3 ERRORS found!
# 5 ERRORS found!
# 6 ERRORS found!
# 6 ERRORS found!
# 9 ERRORS found!
# 9 ERRORS found!
# 10 ERRORS found!
# 10 ERRORS found!
# WTF BRO U GOT AN ERROR
# 1 ERRORS found!
# 1 ERRORS found!
# 1 ERRORS found!
# 2 ERRORS found!
# 2 ERRORS found!
# 2 ERRORS found!
# 2 ERRORS found!
# 2 ERRORS found!
# 3 ERRORS found!
# 4 ERRORS found!
# 6 ERRORS found!
# 9 ERRORS found!
# 11 ERRORS found!
# 12 ERRORS found!
# 12 ERRORS found!
# WTF BRO U GOT AN ERROR
# 3 ERRORS found!
# 3 ERRORS found!
# 4 ERRORS found!
# 4 ERRORS found!
# 6 ERRORS found!
# 7 ERRORS found!
# 11 ERRORS found!
# 15 ERRORS found!
# 22 ERRORS found!
# 26 ERRORS found!
# 26 ERRORS found!
# WTF BRO U GOT AN ERROR
# 1 ERRORS found!
# 2 ERRORS found!
# 2 ERRORS found!
# 4 ERRORS found!
# 5 ERRORS found!
# 6 ERRORS found!
# ...

# %%
c = np.arange(1, 500, 20)
f2 = lambda x: runner.run(50, x, True)[0]
f2_e = lambda x: runner.run(50, x, True)[1]
nc = np.vectorize(f2)
nc_2 = np.vectorize(f2_e)
plt.plot(c, nc(c), c, nc_2(c));
plt.show()
# Out:
# 1 ERRORS found!
# 1 ERRORS found!
# 1 ERRORS found!
# 1 ERRORS found!
# 1 ERRORS found!
# 1 ERRORS found!
# 1 ERRORS found!
# 1 ERRORS found!
# WTF BRO U GOT AN ERROR
# 1 ERRORS found!
# 1 ERRORS found!
# 1 ERRORS found!
# 1 ERRORS found!
# 1 ERRORS found!
# 1 ERRORS found!
# 1 ERRORS found!
# 1 ERRORS found!
# 1 ERRORS found!
# 1 ERRORS found!
# 1 ERRORS found!
# 2 ERRORS found!
# 2 ERRORS found!
# 2 ERRORS found!
# 3 ERRORS found!
# 5 ERRORS found!
# 5 ERRORS found!
# 5 ERRORS found!
# WTF BRO U GOT AN ERROR
# 1 ERRORS found!
# 1 ERRORS found!
# 1 ERRORS found!
# 3 ERRORS found!
# 3 ERRORS found!
# 3 ERRORS found!
# 3 ERRORS found!
# 4 ERRORS found!
# 4 ERRORS found!
# 4 ERRORS found!
# 4 ERRORS found!
# 5 ERRORS found!
# 6 ERRORS found!
# 7 ERRORS found!
# 7 ERRORS found!
# 9 ERRORS found!
# 9 ERRORS found!
# WTF BRO U GOT AN ERROR
# 1 ERRORS found!
# 3 ERRORS found!
# 3 ERRORS found!
# 3 ERRORS found!
# 6 ERRORS found!
# 6 ERRORS found!
# 6 ERRORS found!
# 6 ERRORS found!
# ...
